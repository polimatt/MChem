# %%
import pandas as pd

# %%
pd.read_csv('../../Data/TOC/NG_MP_Aut_2024_10_18.txt',sep='\t',skiprows=10)
# Out:
#        Type    Anal. Sample Name   Sample ID  Result(TOC)  Result(TC)  \
# 0   Unknown  NPOC/TN       Blank       Blank          NaN         NaN
# 1   Unknown  NPOC/TN       Blank       Blank          NaN         NaN
# 2   Unknown  NPOC/TN       Blank       Blank          NaN         NaN
# 3   Unknown  NPOC/TN           1   NPOC 5ppm          NaN         NaN
# 4   Unknown  NPOC/TN           1  NPOC 10ppm          NaN         NaN
# 5   Unknown  NPOC/TN           1  NPOC 20ppm          NaN         NaN
# 6   Unknown  NPOC/TN           1  NPOC 50ppm          NaN         NaN
# 7   Unknown  NPOC/TN       Blank       Blank          NaN         NaN
# 8   Unknown  NPOC/TN           1    TN 2 ppm          NaN         NaN
# 9   Unknown  NPOC/TN           1    TN 5 ppm          NaN         NaN
# 10  Unknown  NPOC/TN           1   TN 10 ppm          NaN         NaN
# 11  Unknown  NPOC/TN       Blank       Blank          NaN         NaN
# ...
