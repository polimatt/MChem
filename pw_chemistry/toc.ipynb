# %%
import pandas as pd

# %%
df = pd.read_csv('../../Data/TOC/NG_MP_Aut_2024_10_18.txt',sep='\t',skiprows=10)#[['Sample ID','Result(NPOC)','Result(TN)']]
df.sort_values('Sample ID')
# Out:
#        Type    Anal. Sample Name                  Sample ID  Result(TOC)  \
# 0   Unknown  NPOC/TN       Blank                      Blank          NaN
# 36  Unknown  NPOC/TN       Blank                      Blank          NaN
# 31  Unknown  NPOC/TN       Blank                      Blank          NaN
# 26  Unknown  NPOC/TN       Blank                      Blank          NaN
# 22  Unknown  NPOC/TN       Blank                      Blank          NaN
# 40  Unknown  NPOC/TN       Blank                      Blank          NaN
# 19  Unknown  NPOC/TN       Blank                      Blank          NaN
# 16  Unknown  NPOC/TN    Untitled                      Blank          NaN
# 11  Unknown  NPOC/TN       Blank                      Blank          NaN
# 41  Unknown  NPOC/TN       Blank                      Blank          NaN
# 1   Unknown  NPOC/TN       Blank                      Blank          NaN
# 2   Unknown  NPOC/TN       Blank                      Blank          NaN
# ...
